# %% [markdown]
# <div class="row">
#   <div class="column">
#     <img src="./img/logo-onera.png" width="200">
#   </div>
#   <div class="column">
#     <img src="./img/logo-ISAE_SUPAERO.png" width="200">
#   </div>
# </div>

# %% [markdown]
# # FAST-OAD Tutorial

# %% [markdown]
# FAST-OAD is a framework for performing rapid Overall Aircraft Design. The computational core of FAST-OAD is based on the  [OpenMDAO framework](https://openmdao.org/).

# %% [markdown]
# ## 1. Setting up and analyzing the initial problem

# %% [markdown]
# To organize our work, we propose to use two user folders `data/` and `workdir/`. For instance, in `data/` we store a XML file which describes the [CeRAS reference case](http://ceras.ilr.rwth-aachen.de/trac/wiki/CeRAS/AircraftDesigns/CSR01). In `workdir/`, we store files generated or modified by FAST-OAD.

# %%
import os.path as pth
import openmdao.api as om
import logging
import shutil
import fastoad.api as oad


DATA_FOLDER_PATH = "data"

WORK_FOLDER_PATH = "workdir"

CONFIGURATION_FILE = pth.join(WORK_FOLDER_PATH, "oad_process.yml")
SOURCE_FILE = pth.join(DATA_FOLDER_PATH, "problem_inputs_reference.xml")

# For having log messages on screen
logging.basicConfig(level=logging.INFO, format="%(levelname)-8s: %(message)s")

# %% [markdown]
# After defining a configuration file name, we can ask FAST-OAD to generate a default configuration file based on the default OAD model implemented in the framework:

# %%
# oad.generate_configuration_file(
#     CONFIGURATION_FILE, overwrite=True
# )

# The above generated configuration uses the quick and simple Breguet module to compute performances.
# If you want to use the more accurate, much more CPU-costly time-step integration, uncomment and run
# the next line:
# shutil.copy(pth.join(DATA_FOLDER_PATH, "oad_process_timestep_mission.yml"), CONFIGURATION_FILE)

# %% [markdown]
# You can now checkout the generated [configuration file](./workdir/oad_process.yml).

# %% [markdown]
# In this configuration file, we have specified an input file name 'problem_inputs.xml'. We can ask FAST-OAD to generate the inputs of the default model with the CeRAS parameters as default values:

# %%
oad.generate_inputs(CONFIGURATION_FILE, SOURCE_FILE, overwrite=True)
# Out:
# INFO    : Loading FAST-OAD plugin bundled
# INFO    : Loading bundles from fastoad.models
# INFO    : Installed bundle fastoad.models.performances.mission.mission_definition.resources.__init__ (ID 25 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.__init__ (ID 48 )
# INFO    : Installed bundle fastoad.models.performances.mission.openmdao.payload_range (ID 18 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.__init__ (ID 36 )
# INFO    : Installed bundle fastoad.models.performances.__init__ (ID 10 )
# INFO    : Installed bundle fastoad.models.performances.mission.exceptions (ID 24 )
# INFO    : Installed bundle fastoad.models.performances.mission.polar (ID 11 )
# INFO    : Installed bundle fastoad.models.performances.mission.base (ID 34 )
# INFO    : Installed bundle fastoad.models.performances.mission.util (ID 13 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.start (ID 49 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.time_step_base (ID 37 )
# INFO    : Installed bundle fastoad.models.performances.mission.mission_definition.__init__ (ID 26 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.mass_input (ID 50 )
# INFO    : Installed bundle fastoad.models.performances.mission.polar_modifier (ID 12 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.ground_speed_change (ID 51 )
# INFO    : Installed bundle fastoad.models.performances.mission.__init__ (ID 14 )
# INFO    : Installed bundle fastoad.models.performances.mission.mission_definition.mission_builder.input_definition (ID 27 )
# INFO    : Installed bundle fastoad.models.performances.mission.routes (ID 53 )
# INFO    : Installed bundle fastoad.models.performances.mission.mission_definition.mission_builder.constants (ID 28 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.base (ID 52 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.hold (ID 39 )
# INFO    : Installed bundle fastoad.models.performances.mission.mission_definition.mission_builder.structure_builders (ID 29 )
# INFO    : Installed bundle fastoad.models.__init__ (ID 54 )
# INFO    : Installed bundle fastoad.models.performances.mission.openmdao.resources.__init__ (ID 15 )
# INFO    : Installed bundle fastoad.models.performances.mission.mission_definition.mission_builder.__init__ (ID 30 )
# INFO    : Installed bundle fastoad.models.performances.mission.openmdao.mission (ID 19 )
# INFO    : Installed bundle fastoad.models.performances.mission.openmdao.mission_wrapper (ID 17 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.taxi (ID 40 )
# INFO    : Installed bundle fastoad.models.performances.mission.mission_definition.mission_builder.mission_builder (ID 31 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.cruise (ID 41 )
# INFO    : Installed bundle fastoad.models.performances.mission.mission_definition.exceptions (ID 32 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.speed_change (ID 42 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.transition (ID 47 )
# INFO    : Installed bundle fastoad.models.performances.mission.openmdao.__init__ (ID 16 )
# INFO    : Installed bundle fastoad.models.performances.mission.mission_definition.schema (ID 33 )
# INFO    : Installed bundle fastoad.models.performances.mission.openmdao.link_mtow (ID 20 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.takeoff.__init__ (ID 43 )
# INFO    : Installed bundle fastoad.models.performances.mission.openmdao.mission_run (ID 22 )
# INFO    : Installed bundle fastoad.models.performances.mission.openmdao.base (ID 21 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.takeoff.takeoff (ID 44 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.macro_segments (ID 35 )
# INFO    : Installed bundle fastoad.models.performances.mission.mission (ID 23 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.takeoff.end_of_takeoff (ID 45 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.altitude_change (ID 38 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.takeoff.rotation (ID 46 )
# INFO    : Loaded variable descriptions in fastoad.models
# INFO    : Loading FAST-OAD plugin rhea
# INFO    : Loading bundles from rhea.models
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.c_systems.ATA23_communicatoin_systems_weight (ID 77 )
# INFO    : Installed bundle rhea.models.weight.cg.cg_components.compute_cg_loadcase1 (ID 98 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.turboprop_engine.engine_components.High_Pressure_Compressor (ID 112 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.turboprop_engine.tests.__init__ (ID 124 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.turboprop_engine.sizing.__init__ (ID 127 )
# INFO    : Installed bundle rhea.models.loops.compute_wing_area_RHEA (ID 161 )
# INFO    : Installed bundle rhea.models.geometry.geom_components.nacelle.compute_nacelle (ID 168 )
# INFO    : Installed bundle rhea.models.aerodynamics.aerodynamics_high_speed_RHEA (ID 141 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.c_systems.__init__ (ID 76 )
# INFO    : Installed bundle rhea.models.aerodynamics.__init__ (ID 143 )
# INFO    : Installed bundle rhea.models.geometry.geom_components.nacelle.__init__ (ID 169 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.turboprop_engine.engine_components.Thrust (ID 113 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.turboprop_engine.tests.test_ML_TP_L1 (ID 125 )
# INFO    : Installed bundle rhea.models.aerodynamics.components.oswald (ID 144 )
# INFO    : Installed bundle rhea.models.geometry.geometry_RHEA_wing_IN (ID 162 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.e_operational.operational_equipment_weight (ID 55 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.c_systems.ATA49_auxiliary_power_systems_weight (ID 78 )
# INFO    : Installed bundle rhea.models.aerodynamics.components.OEI_effect (ID 146 )
# INFO    : Installed bundle rhea.models.geometry.geom_components.__init__ (ID 170 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.e_operational.operational_items_weight (ID 57 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.c_systems.ATA25_flight_furnishing_systems_weight (ID 79 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.turboprop_engine.engine_components.Compression_Nozzle (ID 114 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.c_systems.ATA30_deice_systems_weight (ID 80 )
# INFO    : Installed bundle rhea.models.aerodynamics.components.cd0_fuselage (ID 145 )
# INFO    : Installed bundle rhea.models.geometry.geom_components.wing.compute_wing_RHEA_IN (ID 171 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.e_operational.__init__ (ID 56 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.c_systems.ATA24_electrical_systems_weight (ID 81 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.c_systems.ATA21_environmental_control_systems_weight (ID 82 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.turboprop_engine.engine_components.Low_Pressure_Compressor (ID 115 )
# INFO    : Installed bundle rhea.models.aerodynamics.components.__init__ (ID 148 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.__init__ (ID 58 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.c_systems.ATA34_navigation_systems_weight (ID 83 )
# INFO    : Installed bundle rhea.models.aerodynamics.components.cd0_nacelle_pylons_TP (ID 147 )
# INFO    : Installed bundle rhea.models.geometry.geom_components.wing.__init__ (ID 172 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.c_systems.ATA22_autoflight_systems_weight (ID 84 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.turboprop_engine.engine_components.Low_Pressure_Turbine (ID 116 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.turboprop_engine.TP_engine_L0 (ID 133 )
# INFO    : Installed bundle rhea.models.aerodynamics.components.cd0_wing (ID 151 )
# INFO    : Installed bundle rhea.models.weight.cg.cg_components.compute_cg_RHEA_IN (ID 99 )
# INFO    : Installed bundle rhea.models.geometry.geom_components.wing.components.compute_wet_area_wing (ID 173 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.mass_breakdown (ID 59 )
# INFO    : Installed bundle rhea.models.weight.cg.cg_components.compute_cg_ratio_aft_RHEA (ID 100 )
# INFO    : Installed bundle rhea.models.aerodynamics.components.high_lift_aero (ID 149 )
# INFO    : Installed bundle rhea.models.geometry.geometry_RHEA2 (ID 163 )
# INFO    : Installed bundle rhea.models.weight.weight_RHEA_sizing (ID 85 )
# INFO    : Installed bundle rhea.models.aerodynamics.components.cd0_total (ID 150 )
# INFO    : Installed bundle rhea.models.geometry.geom_components.wing.components.__init__ (ID 174 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.mass_breakdown_RHEA_OAD (ID 60 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.turboprop_engine.sizing.TP_sizing (ID 128 )
# INFO    : Installed bundle rhea.models.aerodynamics.components.lg_effect (ID 153 )
# INFO    : Installed bundle rhea.models.weight.cg.cg_RHEA_IN (ID 86 )
# INFO    : Installed bundle rhea.models.weight.cg.cg_components.compute_cg_others_RHEA (ID 101 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.turboprop_engine.sizing.Prop_sizing (ID 129 )
# INFO    : Installed bundle rhea.models.geometry.geom_components.wing.components.compute_toc_wing_RHEA (ID 175 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.a_airframe.a1_wing_weight (ID 61 )
# INFO    : Installed bundle rhea.models.weight.cg.cg (ID 87 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.turboprop_engine.engine_components.Propeller (ID 117 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.turboprop_engine.TP_engine_L1 (ID 130 )
# INFO    : Installed bundle rhea.models.aerodynamics.components.compute_low_speed_aero (ID 152 )
# INFO    : Installed bundle rhea.models.geometry.__init__ (ID 177 )
# INFO    : Installed bundle rhea.models.geometry.geom_components.wing.compute_wing_RHEA (ID 176 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.a_airframe.__init__ (ID 62 )
# INFO    : Installed bundle rhea.models.weight.cg.__init__ (ID 88 )
# INFO    : Installed bundle rhea.models.weight.cg.cg_components.compute_cg_flight_controls (ID 89 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.turboprop_engine.ML_TP_L1 (ID 132 )
# INFO    : Installed bundle rhea.models.geometry.geometry_RHEA_sizing (ID 178 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.a_airframe.a6_nacelles_weight (ID 63 )
# INFO    : Installed bundle rhea.models.weight.cg.cg_components.compute_hybrid_propulsion_cg_RHEA (ID 91 )
# INFO    : Installed bundle rhea.models.weight.cg.cg_components.compute_cg_loadcase4 (ID 102 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.turboprop_engine.ML_TP_L1_H2_burn (ID 134 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.d_furniture.ATA33_lighting_weight (ID 64 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.d_furniture.ATA38_water_weight (ID 65 )
# INFO    : Installed bundle rhea.models.weight.cg.cg_components.compute_global_cg (ID 103 )
# INFO    : Installed bundle rhea.models.weight.cg.cg_components.compute_cg_loadcase3 (ID 90 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.turboprop_engine.openmdao (ID 131 )
# INFO    : Installed bundle rhea.models.aerodynamics.components.initialize_in (ID 154 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.d_furniture.ATA35_oxygen_weight (ID 66 )
# INFO    : Installed bundle rhea.models.weight.cg.cg_components.compute_propulsion_cg_RHEA (ID 104 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.turboprop_engine.base (ID 135 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.d_furniture.ATA5345_5347_interior_weight (ID 68 )
# INFO    : Installed bundle rhea.models.weight.weight_RHEA_IN (ID 106 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.turboprop_engine.engine_components.__init__ (ID 118 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.complete_propulsion_inputs (ID 136 )
# INFO    : Installed bundle rhea.models.aerodynamics.components.initialize_cl (ID 155 )
# INFO    : Installed bundle rhea.models.weight.cg.cg_components.compute_max_cg_ratio (ID 92 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.turboprop_engine.engine_components.Expansion_Nozzle (ID 120 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.d_furniture.__init__ (ID 67 )
# INFO    : Installed bundle rhea.models.weight.cg.cg_components.__init__ (ID 94 )
# INFO    : Installed bundle rhea.models.weight.cg.cg_components.compute_cg_ratio_aft (ID 105 )
# INFO    : Installed bundle rhea.models.propulsion.__init__ (ID 137 )
# INFO    : Installed bundle rhea.models.aerodynamics.components.compute_polar (ID 156 )
# INFO    : Installed bundle rhea.models.geometry.geometry_RHEA_IN (ID 164 )
# INFO    : Installed bundle rhea.models.weight.cg.cg_components.compute_cg_tanks_RHEA (ID 93 )
# INFO    : Installed bundle rhea.models.weight.__init__ (ID 107 )
# INFO    : Installed bundle rhea.models.register (ID 138 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.d_furniture.ATA2580_insulation_weight (ID 69 )
# INFO    : Installed bundle rhea.models.weight.weight_RHEA_sizing_OAD (ID 108 )
# INFO    : Installed bundle rhea.models.aerodynamics.aerodynamics_low_speed_RHEA (ID 157 )
# INFO    : Installed bundle rhea.models.geometry.geom_components.fuselage.compute_fuselage (ID 165 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.d_furniture.ATA25_furnishing_weight (ID 70 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.turboprop_engine.engine_components.High_Pressure_Turbine (ID 119 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.turboprop_engine.engine_components.Fuel_Data (ID 121 )
# INFO    : Installed bundle rhea.models.__init__ (ID 139 )
# INFO    : Installed bundle rhea.models.aerodynamics.aerodynamics_takeoff_RHEA (ID 140 )
# INFO    : Installed bundle rhea.models.loops.compute_engine_size (ID 158 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.d_furniture.ATA2510_crew_seats_weight (ID 71 )
# INFO    : Installed bundle rhea.models.weight.cg.cg_components.compute_cg_loadcase2 (ID 95 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.constants (ID 109 )
# INFO    : Installed bundle rhea.models.aerodynamics.constants (ID 142 )
# INFO    : Installed bundle rhea.models.loops.__init__ (ID 159 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.c_systems.ATA27_flight_control_systems_weight (ID 73 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.__init__ (ID 110 )
# INFO    : Installed bundle rhea.models.geometry.geom_components.fuselage.__init__ (ID 166 )
# INFO    : Installed bundle rhea.models.weight.cg.cg_components.compute_global_cg_RHEA (ID 96 )
# INFO    : Installed bundle rhea.models.loops.compute_wing_position (ID 160 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.mass_breakdown_RHEA (ID 72 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.turboprop_engine.engine_components.Power_Turbine (ID 122 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.turboprop_engine.__init__ (ID 126 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.c_systems.ATA26_fire_systems_weight (ID 74 )
# INFO    : Installed bundle rhea.models.weight.cg.cg_components.compute_cg_others (ID 97 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.turboprop_engine.engine_components.Ram (ID 123 )
# INFO    : Installed bundle rhea.models.propulsion.fuel_engine.turboprop_engine.engine_components.Combustor (ID 111 )
# INFO    : Installed bundle rhea.models.geometry.geom_components.compute_geom_RHEA (ID 167 )
# INFO    : Installed bundle rhea.models.weight.mass_breakdown.c_systems.ATA29_hydraulic_systems_weight (ID 75 )
# WARNING : Failed to import module rhea.models.weight.cg
# INFO    : Loading FAST-OAD plugin cs25
# INFO    : Loading bundles from fastoad_cs25.models
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.c_systems.c5_fixed_operational_systems_weight (ID 212 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.__init__ (ID 257 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.ht.compute_horizontal_tail (ID 320 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.a_airframe.a1_wing_weight (ID 193 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.vt.components.compute_vt_clalpha (ID 302 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.c_systems.constants (ID 213 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.compute_cg_wing (ID 225 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.vt.components.compute_vt_mac (ID 303 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.b_propulsion.sum (ID 191 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.c_systems.c2_life_support_systems_weight (ID 215 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.load_cases.__init__ (ID 233 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.aerodynamics_low_speed (ID 256 )
# INFO    : Installed bundle fastoad_cs25.models.handling_qualities.tail_sizing.__init__ (ID 288 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.vt.components.__init__ (ID 304 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.__init__ (ID 226 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.cd0 (ID 260 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.compute_polar (ID 278 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.c_systems.__init__ (ID 214 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.load_cases.compute_cg_loadcase2 (ID 234 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.vt.components.compute_vt_distance (ID 305 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.ht.__init__ (ID 314 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.payload (ID 192 )
# INFO    : Installed bundle fastoad_cs25.models.handling_qualities.tail_sizing.compute_ht_area (ID 290 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.d_furniture.d1_cargo_configuration_weight (ID 203 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.aerodynamics_high_speed (ID 258 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.cd0_nacelles_pylons (ID 279 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.ht.components.compute_ht_mac (ID 315 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.a_airframe.a6_pylons_weight (ID 194 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.c_systems.c1_power_systems_weight (ID 216 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.load_cases.compute_cg_loadcase1 (ID 235 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.ht.components.__init__ (ID 316 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.vt.components.compute_vt_chords (ID 306 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.a_airframe.a4_flight_control_weight (ID 195 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.c_systems.c6_flight_kit_weight (ID 218 )
# INFO    : Installed bundle fastoad_cs25.models.handling_qualities.compute_static_margin (ID 291 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.vt.components.compute_vt_sweep (ID 307 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.fuselage.compute_fuselage (ID 308 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.a_airframe.constants (ID 196 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.c_systems.sum (ID 217 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.load_cases.compute_cg_loadcase4 (ID 236 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.cd0_vt (ID 280 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.ht.components.compute_ht_cl_alpha (ID 317 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.external.xfoil.resources.__init__ (ID 281 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.ht.components.compute_ht_chords (ID 318 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.a_airframe.__init__ (ID 197 )
# INFO    : Installed bundle fastoad_cs25.models.loops.wing_area_component.update_wing_area_geom (ID 292 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.ht.components.compute_ht_sweep (ID 319 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.external.xfoil.xfoil699.__init__ (ID 284 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.compute_wetted_area (ID 321 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.a_airframe.a2_fuselage_weight (ID 198 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.external.xfoil.__init__ (ID 282 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.__init__ (ID 335 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.a_airframe.a7_paint_weight (ID 199 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.compute_cg_others (ID 227 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.oswald (ID 259 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.a_airframe.a3_empennage_weight (ID 200 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.a_airframe.a5_landing_gear_weight (ID 202 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.external.xfoil.xfoil_polar (ID 283 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.fuselage.__init__ (ID 309 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.__init__ (ID 322 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.compute_reynolds (ID 261 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.a_airframe.sum (ID 201 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.c_systems.c3_navigation_systems_weight (ID 219 )
# INFO    : Installed bundle fastoad_cs25.models.loops.wing_area_component.update_wing_area_aero (ID 293 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.fuselage.compute_cnbeta_fuselage (ID 310 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.update_mlg (ID 237 )
# INFO    : Installed bundle fastoad_cs25.models.loops.constants (ID 295 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.components.compute_l1_l4 (ID 323 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.compute_vt_cg (ID 228 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.cd0_fuselage (ID 262 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.external.__init__ (ID 285 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.__init__ (ID 311 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.components.compute_mac_wing (ID 324 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.load_cases.compute_cg_loadcases (ID 230 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.compute_global_cg (ID 238 )
# INFO    : Installed bundle fastoad_cs25.models.loops.wing_area_component.__init__ (ID 294 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.components.compute_mfw (ID 325 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.d_furniture.d2_passenger_seats_weight (ID 204 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.compute_cg_tanks (ID 229 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.cd0_ht (ID 263 )
# INFO    : Installed bundle fastoad_cs25.models.handling_qualities.__init__ (ID 286 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.nacelle_pylons.compute_nacelle_pylons (ID 312 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.components.compute_wet_area_wing (ID 326 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg (ID 220 )
# INFO    : Installed bundle fastoad_cs25.models.loops.__init__ (ID 296 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.components.__init__ (ID 327 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.constants (ID 221 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.resources.__init__ (ID 264 )
# INFO    : Installed bundle fastoad_cs25.models.handling_qualities.tail_sizing.compute_tail_areas (ID 287 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.__init__ (ID 222 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.nacelle_pylons.__init__ (ID 313 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.components.compute_sweep_wing (ID 328 )
# INFO    : Installed bundle fastoad_cs25.models.handling_qualities.tail_sizing.compute_vt_area (ID 289 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.components.compute_toc_wing (ID 329 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.__init__ (ID 265 )
# INFO    : Installed bundle fastoad_cs25.models.loops.compute_wing_position (ID 297 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.components.compute_l2_l3 (ID 330 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.compute_cg_control_surfaces (ID 223 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.compute_ht_cg (ID 239 )
# INFO    : Installed bundle fastoad_cs25.models.loops.compute_wing_area (ID 298 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.components.compute_y_wing (ID 331 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.load_cases.compute_cg_loadcase_base (ID 231 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.high_lift_aero (ID 266 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.constants (ID 299 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.components.compute_x_wing (ID 332 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.vt.compute_vertical_tail (ID 300 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.components.compute_b_50 (ID 333 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.load_cases.compute_cg_loadcase3 (ID 232 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.compute_wing (ID 334 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.compute_max_cg_ratio (ID 224 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.utils.friction_drag (ID 267 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.vt.__init__ (ID 301 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.utils.cd0_lifting_surface (ID 268 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.cd_compressibility (ID 270 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.wing_global_positions (ID 336 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geometry (ID 338 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.cs25 (ID 181 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.utils.__init__ (ID 269 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.compute_aero_center (ID 337 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.profiles.profile (ID 341 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.e_crew.crew_weight (ID 179 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.profiles.profile_getter (ID 339 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.aerodynamics_landing (ID 253 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.e_crew.__init__ (ID 180 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.b_propulsion.__init__ (ID 190 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.profiles.resources.__init__ (ID 340 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.profiles.__init__ (ID 342 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.constants (ID 182 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.d_furniture.constants (ID 205 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.update_mlw_and_mzfw (ID 183 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.b_propulsion.constants (ID 186 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.d_furniture.__init__ (ID 206 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.compute_cg_ratio_aft (ID 240 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.compute_alpha (ID 271 )
# INFO    : Installed bundle fastoad_cs25.models.weight.constants (ID 241 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.__init__ (ID 184 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.d_furniture.d5_toilets_weight (ID 207 )
# INFO    : Installed bundle fastoad_cs25.models.weight.__init__ (ID 242 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.d_furniture.d4_security_kit_weight (ID 208 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.d_furniture.d3_food_water_weight (ID 209 )
# INFO    : Installed bundle fastoad_cs25.models.weight.weight (ID 243 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.mass_breakdown (ID 185 )
# INFO    : Installed bundle fastoad_cs25.models.propulsion.fuel_propulsion.rubber_engine.rubber_engine (ID 245 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.cd0_total (ID 272 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.d_furniture.sum (ID 210 )
# INFO    : Installed bundle fastoad_cs25.models.propulsion.fuel_propulsion.__init__ (ID 244 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.compute_cl_alpha (ID 273 )
# INFO    : Installed bundle fastoad_cs25.models.propulsion.__init__ (ID 250 )
# INFO    : Installed bundle fastoad_cs25.models.propulsion.fuel_propulsion.rubber_engine.constants (ID 246 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.cd0_wing (ID 274 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.c_systems.c4_transmissions_systems_weight (ID 211 )
# INFO    : Installed bundle fastoad_cs25.models.propulsion.fuel_propulsion.rubber_engine.__init__ (ID 247 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.cd_trim (ID 275 )
# INFO    : Installed bundle fastoad_cs25.models.propulsion.fuel_propulsion.rubber_engine.openmdao (ID 248 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.compute_max_cl_landing (ID 277 )
# INFO    : Installed bundle fastoad_cs25.models.propulsion.fuel_propulsion.rubber_engine.exceptions (ID 249 )
# INFO    : Installed bundle fastoad_cs25.models.constants (ID 251 )
# INFO    : Installed bundle fastoad_cs25.models.__init__ (ID 252 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.initialize_cl (ID 276 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.b_propulsion.b3_unconsumables_weight (ID 187 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.constants (ID 255 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.b_propulsion.b1_engine_weight (ID 188 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.b_propulsion.b2_fuel_lines_weight (ID 189 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.aerodynamics_takeoff (ID 254 )
# INFO    : Loaded variable descriptions in fastoad_cs25.models
# INFO    : Problem inputs written in /Users/s.delbecq/PycharmProjects/RHEA/notebooks/workdir/problem_inputs.xml
# '/Users/s.delbecq/PycharmProjects/RHEA/notebooks/workdir/problem_inputs.xml'

# %% [markdown]
# You can now checkout the generated [input file](./workdir/problem_inputs.xml). As shown previously in the user file architecture, the values in this file can be modified by the user and will be considered by FAST-OAD when executing a computational process.

# %% [markdown]
# A useful feature that FAST-OAD provides is to list the outputs of the model defined in the configuration file:

# %%
oad.list_variables(CONFIGURATION_FILE)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>NAME</th>
#       <th>I/O</th>
#       <th>DESCRIPTION</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>data:TLAR:NPAX</td>
#       <td>IN</td>
#       <td>top-level requirement: number of passengers, assuming a classic eco/business class repartition</td>
#     </tr>
#     <tr>
#       <td>data:TLAR:approach_speed</td>
#       <td>IN</td>
#       <td>top-level requirement: approach speed</td>
#     </tr>
#     <tr>
#       <td>data:TLAR:cruise_mach</td>
#       <td>IN</td>
#       <td>Input defined by the mission.</td>
#     </tr>
#     <tr>
#       <td>data:TLAR:range</td>
#       <td>IN</td>
#       <td>Input defined by the mission.</td>
#     </tr>
#     <tr>
#       <td>data:aerodynamics:aircraft:landing:CL_max</td>
#       <td>IN</td>
#       <td>maximum lift coefficient in landing conditions</td>
#     </tr>
#     <tr>
#       <td>data:aerodynamics:aircraft:low_speed:DCD_ext</td>
#       <td>IN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>data:aerodynamics:aircraft:takeoff:mach</td>
#       <td>IN</td>
#       <td>considered Mach number for takeoff phase</td>
#     </tr>
#     <tr>
#       <td>data:geometry:cabin:aisle_width</td>
#       <td>IN</td>
#       <td>width of aisles</td>
#     </tr>
#     <tr>
#       <td>data:geometry:cabin:crew_count:technical</td>
#       <td>IN</td>
#       <td>number of technical crew members</td>
#     </tr>
#     <tr>
#       <td>data:geometry:cabin:exit_width</td>
#       <td>IN</td>
#       <td>width of exits</td>
#     </tr>
#     <tr>
#       <td>data:geometry:cabin:seats:economical:count_by_row</td>
#       <td>IN</td>
#       <td>number of economical class seats along width</td>
#     </tr>
#     <tr>
#       <td>data:geometry:cabin:seats:economical:length</td>
#       <td>IN</td>
#       <td>length of economical class seats</td>
#     </tr>
#     <tr>
#       <td>data:geometry:cabin:seats:economical:width</td>
#       <td>IN</td>
#       <td>width of economical class seats</td>
#     </tr>
#     <tr>
#       <td>data:geometry:flap:chord_ratio</td>
#       <td>IN</td>
#       <td>mean value of (flap chord)/(section chord)</td>
#     </tr>
#     <tr>
#       <td>data:geometry:flap:span_ratio</td>
#       <td>IN</td>
#       <td>ratio (width of flaps)/(total span)</td>
#     </tr>
#     <tr>
#       <td>data:geometry:has_T_tail</td>
#       <td>IN</td>
#       <td>0=horizontal tail is attached to fuselage / 1=horizontal tail is attached to top of vertical tail</td>
#     </tr>
#     <tr>
#       <td>data:geometry:horizontal_tail:aspect_ratio</td>
#       <td>IN</td>
#       <td>aspect ratio of horizontal tail</td>
#     </tr>
#     <tr>
#       <td>data:geometry:horizontal_tail:sweep_25</td>
#       <td>IN</td>
#       <td>sweep angle at 25% chord of horizontal tail</td>
#     </tr>
#     <tr>
#       <td>data:geometry:horizontal_tail:taper_ratio</td>
#       <td>IN</td>
#       <td>taper ratio of horizontal tail</td>
#     </tr>
#     <tr>
#       <td>data:geometry:horizontal_tail:thickness_ratio</td>
#       <td>IN</td>
#       <td>thickness ratio of horizontal tail</td>
#     </tr>
#     <tr>
#       <td>data:geometry:propulsion:engine:count</td>
#       <td>IN</td>
#       <td>number of engines</td>
#     </tr>
#     <tr>
#       <td>data:geometry:propulsion:engine:y_ratio</td>
#       <td>IN</td>
#       <td>engine position with respect to total span</td>
#     </tr>
#     <tr>
#       <td>data:geometry:propulsion:layout</td>
#       <td>IN</td>
#       <td>position of engines (1=under the wing / 2=rear fuselage)</td>
#     </tr>
#     <tr>
#       <td>data:geometry:propulsion:propeller:B</td>
#       <td>IN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>data:geometry:slat:chord_ratio</td>
#       <td>IN</td>
#       <td>mean value of slat chord)/(section chord)</td>
#     </tr>
#     <tr>
#       <td>data:geometry:slat:span_ratio</td>
#       <td>IN</td>
#       <td>ratio (width of slats)/(total span)</td>
#     </tr>
#     <tr>
#       <td>data:geometry:vertical_tail:aspect_ratio</td>
#       <td>IN</td>
#       <td>aspect ratio of vertical tail</td>
#     </tr>
#     <tr>
#       <td>data:geometry:vertical_tail:sweep_25</td>
#       <td>IN</td>
#       <td>sweep angle at 25% chord of vertical tail</td>
#     </tr>
#     <tr>
#       <td>data:geometry:vertical_tail:taper_ratio</td>
#       <td>IN</td>
#       <td>taper ratio of vertical tail</td>
#     </tr>
#     <tr>
#       <td>data:geometry:vertical_tail:thickness_ratio</td>
#       <td>IN</td>
#       <td>thickness ratio of vertical tail</td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:aspect_ratio</td>
#       <td>IN</td>
#       <td>wing aspect ratio</td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:kink:span_ratio</td>
#       <td>IN</td>
#       <td>ratio (Y-position of kink)/(semi-span)</td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:spar_ratio:front:kink</td>
#       <td>IN</td>
#       <td>ratio (front spar position)/(chord length) at wing kink</td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:spar_ratio:front:root</td>
#       <td>IN</td>
#       <td>ratio (front spar position)/(chord length) at wing root</td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:spar_ratio:front:tip</td>
#       <td>IN</td>
#       <td>ratio (front spar position)/(chord length) at wing tip</td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:spar_ratio:rear:kink</td>
#       <td>IN</td>
#       <td>ratio (rear spar position)/(chord length) at wing kink</td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:spar_ratio:rear:root</td>
#       <td>IN</td>
#       <td>ratio (rear spar position)/(chord length) at wing root</td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:spar_ratio:rear:tip</td>
#       <td>IN</td>
#       <td>ratio (rear spar position)/(chord length) at wing tip</td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:sweep_25</td>
#       <td>IN</td>
#       <td>sweep angle at 25% chord of wing</td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:virtual_taper_ratio</td>
#       <td>IN</td>
#       <td>taper ratio of wing computed from virtual root chord</td>
#     </tr>
#     <tr>
#       <td>data:handling_qualities:static_margin:target</td>
#       <td>IN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>data:load_case:lc1:U_gust</td>
#       <td>IN</td>
#       <td>gust vertical speed for sizing load case 1 (gust with minimum aircraft mass)</td>
#     </tr>
#     <tr>
#       <td>data:load_case:lc1:Vc_EAS</td>
#       <td>IN</td>
#       <td>equivalent air speed for sizing load case 1 (gust with minimum aircraft mass)</td>
#     </tr>
#     <tr>
#       <td>data:load_case:lc1:altitude</td>
#       <td>IN</td>
#       <td>altitude for sizing load case 1 (gust with minimum aircraft mass)</td>
#     </tr>
#     <tr>
#       <td>data:load_case:lc2:U_gust</td>
#       <td>IN</td>
#       <td>gust vertical speed for sizing load case 2 (gust with maximum aircraft mass)</td>
#     </tr>
#     <tr>
#       <td>data:load_case:lc2:Vc_EAS</td>
#       <td>IN</td>
#       <td>equivalent air speed for sizing load case 2 (gust with maximum aircraft mass)</td>
#     </tr>
#     <tr>
#       <td>data:load_case:lc2:altitude</td>
#       <td>IN</td>
#       <td>altitude for sizing load case 2 (gust with maximum aircraft mass)</td>
#     </tr>
#     <tr>
#       <td>data:mission:sizing:ISA_offset</td>
#       <td>IN</td>
#       <td>Input defined by the mission.</td>
#     </tr>
#     <tr>
#       <td>data:mission:sizing:climb:first_segment:CAS</td>
#       <td>IN</td>
#       <td>Input defined by the mission.</td>
#     </tr>
#     <tr>
#       <td>data:mission:sizing:climb:second_segment:CAS</td>
#       <td>IN</td>
#       <td>Input defined by the mission.</td>
#     </tr>
#     <tr>
#       <td>data:mission:sizing:climb:thrust_rate</td>
#       <td>IN</td>
#       <td>Input defined by the mission.</td>
#     </tr>
#     <tr>
#       <td>data:mission:sizing:descent:thrust_rate</td>
#       <td>IN</td>
#       <td>Input defined by the mission.</td>
#     </tr>
#     <tr>
#       <td>data:mission:sizing:diversion:distance</td>
#       <td>IN</td>
#       <td>Input defined by the mission.</td>
#     </tr>
#     <tr>
#       <td>data:mission:sizing:holding:duration</td>
#       <td>IN</td>
#       <td>Input defined by the mission.</td>
#     </tr>
#     <tr>
#       <td>data:mission:sizing:init

# %% [markdown]
# Another useful feature is to list the modules of the model defined in the configuration file:

# %%
oad.list_modules(CONFIGURATION_FILE)
# api.list_modules(CONFIGURATION_FILE, verbose=True) # Use this line instead of the previous one for detailed information (text format only)
# Out:
# <table>
# <tbody>
# <tr><td>AVAILABLE MODULE IDENTIFIERS            </td><td>MODULE PATH                                                                                                                                         </td></tr>
# <tr><td>fastoad.aerodynamics.highspeed.legacy   </td><td>/opt/homebrew/Caskroom/miniforge/base/envs/RHEA/lib/python3.8/site-packages/fastoad_cs25/models/aerodynamics/aerodynamics_high_speed.py             </td></tr>
# <tr><td>fastoad.aerodynamics.landing.legacy     </td><td>/opt/homebrew/Caskroom/miniforge/base/envs/RHEA/lib/python3.8/site-packages/fastoad_cs25/models/aerodynamics/aerodynamics_landing.py                </td></tr>
# <tr><td>fastoad.aerodynamics.lowspeed.legacy    </td><td>/opt/homebrew/Caskroom/miniforge/base/envs/RHEA/lib/python3.8/site-packages/fastoad_cs25/models/aerodynamics/aerodynamics_low_speed.py              </td></tr>
# <tr><td>fastoad.aerodynamics.takeoff.legacy     </td><td>/opt/homebrew/Caskroom/miniforge/base/envs/RHEA/lib/python3.8/site-packages/fastoad_cs25/models/aerodynamics/aerodynamics_takeoff.py                </td></tr>
# <tr><td>fastoad.geometry.global_chord_positions </td><td>/opt/homebrew/Caskroom/miniforge/base/envs/RHEA/lib/python3.8/site-packages/fastoad_cs25/models/geometry/wing_global_positions.py                   </td></tr>
# <tr><td>fastoad.geometry.legacy                 </td><td>/opt/homebrew/Caskroom/miniforge/base/envs/RHEA/lib/python3.8/site-packages/fastoad_cs25/models/geometry/geometry.py                                </td></tr>
# <tr><td>fastoad.handling_qualities.static_margin</td><td>/opt/homebrew/Caskroom/miniforge/base/envs/RHEA/lib/python3.8/site-packages/fastoad_cs25/models/handling_qualities/compute_static_margin.py         </td></tr>
# <tr><td>fastoad.handling_qualities.tail_sizing  </td><td>/opt/homebrew/Caskroom/miniforge/base/envs/RHEA/lib/python3.8/site-packages/fastoad_cs25/models/handling_qualities/tail_sizing/compute_tail_areas.py</td></tr>
# <tr><td>fastoad.loop.wing_area                  </td><td>/opt/homebrew/Caskroom/miniforge/base/envs/RHEA/lib/python3.8/site-packages/fastoad_cs25/models/loops/compute_wing_area.py                          </td></tr>
# <tr><td>fastoad.loop.wing_position              </td><td>/opt/homebrew/Caskroom/miniforge/base/envs/RHEA/lib/python3.8/site-packages/fastoad_cs25/models/loops/compute_wing_position.py                      </td></tr>
# <tr><td>fastoad.mass_performances.compute_MTOW  </td><td>/opt/homebrew/Caskroom/miniforge/base/envs/RHEA/lib/python3.8/site-packages/fastoad/models/performances/mission/openmdao/link_mtow.py               </td></tr>
# <tr><td>fastoad.performances.mission            </td><td>/opt/homebrew/Caskroom/miniforge/base/envs/RHEA/lib/python3.8/site-packages/fastoad/models/performances/mission/openmdao/mission.py                 </td></tr>
# <tr><td>fastoad.performances.payload_range      </td><td>/opt/homebrew/Caskroom/miniforge/base/envs/RHEA/lib/python3.8/site-packages/fastoad/models/performances/mission/openmdao/payload_range.py           </td></tr>
# <tr><td>fastoad.weight.legacy                   </td><td>/opt/homebrew/Caskroom/miniforge/base/envs/RHEA/lib/python3.8/site-packages/fastoad_cs25/models/weight/weight.py                                    </td></tr>
# <tr><td>rhea.aerodynamics.highspeed             </td><td>/Users/s.delbecq/PycharmProjects/RHEA/rhea/models/aerodynamics/aerodynamics_high_speed_RHEA.py                                                      </td></tr>
# <tr><td>rhea.aerodynamics.lowspeed              </td><td>/Users/s.delbecq/PycharmProjects/RHEA/rhea/models/aerodynamics/aerodynamics_low_speed_RHEA.py                                                       </td></tr>
# <tr><td>rhea.aerodynamics.takeoff               </td><td>/Users/s.delbecq/PycharmProjects/RHEA/rhea/models/aerodynamics/aerodynamics_takeoff_RHEA.py                                                         </td></tr>
# <tr><td>rhea.geometry.RHEA2                     </td><td>/Users/s.delbecq/PycharmProjects/RHEA/rhea/models/geometry/geometry_RHEA2.py                                                                        </td></tr>
# <tr><td>rhea.geometry.RHEA_IN                   </td><td>/Users/s.delbecq/PycharmProjects/RHEA/rhea/models/geometry/geometry_RHEA_IN.py                                                                      </td></tr>
# <tr><td>rhea.geometry.sizing                    </td><td>/Users/s.delbecq/PycharmProjects/RHEA/rhea/models/geometry/geometry_RHEA_sizing.py                                                                  </td></tr>
# <tr><td>rhea.geometry.wing_IN                   </td><td>/Users/s.delbecq/PycharmProjects/RHEA/rhea/models/geometry/geometry_RHEA_wing_IN.py                                                                 </td></tr>
# <tr><td>rhea.loop.engine_size                   </td><td>/Users/s.delbecq/PycharmProjects/RHEA/rhea/models/loops/compute_engine_size.py                                                                      </td></tr>
# <tr><td>rhea.loop.wing_area                     </td><td>/Users/s.delbecq/PycharmProjects/RHEA/rhea/models/loops/compute_wing_area_RHEA.py                                                                   </td></tr>
# <tr><td>rhea.loop.wing_position                 </td><td>/Users/s.delbecq/PycharmProjects/RHEA/rhea/models/loops/compute_wing_position.py                                                                    </td></tr>
# <tr><td>rhea.propulsion.propeller_sizing        </td><td>/Users/s.delbecq/PycharmProjects/RHEA/rhea/models/propulsion/fuel_engine/turboprop_engine/sizing/Prop_sizing.py                                     </td></tr>
# <tr><td>rhea.propulsion.turboprop_sizing        </td><td>/Users/s.delbecq/PycharmProjects/RHEA/rhea/models/propulsion/fuel_engine/turboprop_engine/sizing/TP_sizing.py                                       </td></tr>
# <tr><td>rhea.weight.IN                          </td><td>/Users/s.delbecq/PycharmProjects/RHEA/rhea/models/weight/weight_RHEA_IN.py                                                                          </td></tr>
# <tr><td>rhea.weight.sizing                      </td><td>/Users/s.delbecq/PycharmProjects/RHEA/rhea/models/weight/weight_RHEA_sizing.py                                                                      </td></tr>
# <tr><td>rhea.weight.sizing_OAD                  </td><td>/Users/s.delbecq/PycharmProjects/RHEA/rhea/models/weight/weight_RHEA_sizing_OAD.py                                                                  </td></tr>
# <tr><td>AVAILABLE PROPULSION WRAPPER IDENTIFIERS</td><td>MODULE PATH                                                                                                                                         </td></tr>
# <tr><td>fastoad.wrapper.propulsion.rubber_engine</td><td>/opt/homebrew/Caskroom/miniforge/base/envs/RHEA/lib/python3.8/site-packages/fastoad_cs25/models/propulsion/fuel_propulsion/rubber_engine/openmdao.py</td></tr>
# <tr><td>rhea.wrapper.propulsion.ML_TP_L1        </td><td>/Users/s.delbecq/PycharmProjects/RHEA/rhea/models/propulsion/fuel_engine/turboprop_engine/openmdao.py                                               </td></tr>
# <tr><td>rhea.wrapper.propulsion.ML_TP_L1_H2_burn</td><td>/Users/s.delbecq/PycharmProjects/RHEA/rhea/models/propulsion/fuel_engine/turboprop_engine/openmdao.py                                               </td></tr>
# <tr><td>rhea.wrapper.propulsion.TP_engine_L0    </td><td>/Users/s.delbecq/PycharmProjects/RHEA/rhea/models/propulsion/fuel_engine/turboprop_engine/openmdao.py                                               </td></tr>
# <tr><td>rhea.wrapper.propulsion.TP_engine_L1    </td><td>/Users/s.delbecq/PycharmProjects/RHEA/rhea/models/propulsion/fuel_engine/turboprop_engine/openmdao.py                                               </td></tr>
# </tbody>
# </table>

# %% [markdown]
# Another useful feature is the [N2 diagram](http://openmdao.org/twodocs/versions/latest/basic_guide/make_n2.html) visualization available in OpenMDAO to see the structure of the model:

# %%
N2_FILE = pth.join(WORK_FOLDER_PATH, "n2.html")
oad.write_n2(CONFIGURATION_FILE, N2_FILE, overwrite=True)
from IPython.display import IFrame

IFrame(src=N2_FILE, width="100%", height="500px")
# Out:
# INFO    : N2 diagram written in /Users/s.delbecq/PycharmProjects/RHEA/notebooks/workdir/n2.html
#         <iframe
#             width="100%"
#             height="500px"
#             src="workdir/n2.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Alternatively, you can use [WhatsOpt](https://github.com/OneraHub/WhatsOpt-Doc#whatsopt-documentation) as a web service to generate the XDSM of the problem.
#
# *This command requires internet access and can take some time (~ 1 minute on the first run), so it is currently deactivated, but feel free to uncomment these lines.*

# %%
# XDSM_FILE = pth.join(WORK_FOLDER_PATH, 'xdsm.html')
# oad.write_xdsm(CONFIGURATION_FILE, XDSM_FILE, overwrite=True)
# from IPython.display import IFrame
# IFrame(src=XDSM_FILE, width='100%', height='500px')

# %% [markdown]
# ## 2. Running your first MDA

# %% [markdown]
# ### CeRAS
# Here we run an MDA, that is solving the multidisciplinary couplings using the different nested solvers in the model, without running the optimization problem even if it is defined in the configuration file.
#
# *(This run should take around 10 seconds)*

# %%
eval_problem = oad.evaluate_problem(CONFIGURATION_FILE, overwrite=True)
# Out:
# INFO    : Mission computation - iteration 0 : Using mission definition.
# INFO    : Mission computation - iteration 1 : Using mission definition.
# INFO    : Mission computation - iteration 2 : Using mission definition.
# INFO    : Mission computation - iteration 3 : Using mission definition.
# INFO    : Mission computation - iteration 4 : Using mission definition.
# INFO    : Mission computation - iteration 5 : Using mission definition.
# INFO    : Mission computation - iteration 6 : Using mission definition.
# INFO    : Mission computation - iteration 7 : Using mission definition.
# INFO    : Computation finished after 54.65 seconds
# INFO    : Problem outputs written in /Users/s.delbecq/PycharmProjects/RHEA/notebooks/workdir/problem_outputs.xml
# NL: NLBGS Converged in 8 iterations

# %% [markdown]
# > _**Note**: the warning you see at end of computation is normal. FAST-OAD allows to define validity domain for each model, and the propulsion model has been validated for a certain range of turbine inlet temperature (a.k.a. T4). The T4 value we use is slightly outside the validated range, hence the warning. The check of validity domain issues warnings as soon as a value is outside the bounds, but in the end, it's up to the user to decide if the problem is real or not, though it may require a certain knowledge about the used models.
# > In this case, the model has been validated for T4 between 1400K and 1600K and using it for a value of 1633K can be considered as OK._
#
# Let's save these results. We will use them in the next notebook, that shows some post-processing utilities.

# %%
OUTPUT_FILE = pth.join(WORK_FOLDER_PATH, "problem_outputs.xml")

# %% [markdown]
# The `variable-viewer` provides a way to inspect the content of the XML file. The dropdown lists above the table allow to filter the displayed variable.

# %%
oad.variable_viewer(OUTPUT_FILE)
# Out:
# VBox(children=(HBox(children=(Button(description='Load', icon='upload', style=ButtonStyle(), tooltip='Load the…

# %%
INPUT_FILE = pth.join(WORK_FOLDER_PATH, "problem_inputs.xml")
oad.variable_viewer(INPUT_FILE)
# Out:
# VBox(children=(HBox(children=(Button(description='Load', icon='upload', style=ButtonStyle(), tooltip='Load the…

# %% [markdown]
# You can also do this operation through Python like this:

# %% [markdown]
# ## 3. Running your first MDO
#
# ## CeRAS 2750 nm optimization
#
# It is possible to run an optimization problem on top of your analysis. Thus, you can choose to set some global inputs as design variables, and global outputs as constraints or the objective. Here is an example given in the default configuration file that aims at:
# - minimizing the fuel consumption for the mission (objective),
# - with respect to the wing aspect ratio (design variables),
# - subject to a wing span limit (constraints).
#
# The last part of the configuration file .yaml is where this optimization problem is defined:
#
# ```yaml
# optimization:  # This section is needed only if optimization process is run
#   design_variables:
#     - name: data:geometry:wing:aspect_ratio
#       lower: 9.0
#       upper: 18.0
#   constraints:
#     - name: data:geometry:wing:span
#       upper: 60.0
#   objective:
#     - name: data:mission:sizing:needed_block_fuel
#       scaler: 1.e-4
# ```
#
# Note that we need to use [scaling](https://openmdao.org/twodocs/versions/latest/features/core_features/defining_components/scaling.html) on the objective (fuel mass for the mission) so that it has the same order of magnitude than the design variable (wing aspect ratio) by adding the line `scaler = 1e-4`. Without this the optimizer might not detect that the steps it makes on the wing aspect ratio has an effect on decreasing the fuel mass and could result in an early stop.
#
#
# *(This run should take around 3 minutes)*

# %%
# Set back the inputs from the reference CeRAS 2750 nm
oad.generate_inputs(CONFIGURATION_FILE, SOURCE_FILE, overwrite=True)
# Out:
# INFO    : Problem inputs written in /Users/s.delbecq/PycharmProjects/RHEA/notebooks/workdir/problem_inputs.xml
# '/Users/s.delbecq/PycharmProjects/RHEA/notebooks/workdir/problem_inputs.xml'

# %% [markdown]
# To visualize and edit the optimization problem definition (present in the configuration file .yml) you can use the `optimization_viewer` tool. If design variables or constraints have active bounds they are yellow whereas they are red if they are violated. Modifiying the `Initial Value` will modify the input file defined in the configuration file .yml whereas `Value` corresponds to the value found in the output file defined in the configuration file (here it is the 800 nm MDA run).

# %%
oad.optimization_viewer(CONFIGURATION_FILE)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 oad.optimization_viewer(CONFIGURATION_FILE)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/RHEA/lib/python3.8/site-packages/fastoad/cmd/api.py:747, in optimization_viewer(configuration_file_path)
#     745 conf._set_configuration_modifier(_PROBLEM_CONFIGURATOR)
#     746 viewer = OptimizationViewer()
# --> 747 viewer.load(conf)
#     749 return viewer.display()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/RHEA/lib/python3.8/site-packages/fastoad/gui/optimization_viewer.py:149, in OptimizationViewer.load(self, problem_configuration)
#     138         metadata = {
#     139             "type": "objective",
#     140             "initial_value": None,
#    (...)
#     145             "desc": output_variables[name].description,
#     146         }
#     147         optimization_variables[name] = metadata
# --> 149 self.load_variables(optimization_variables)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/RHEA/lib/python3.8/site-packages/fastoad/gui/optimization_viewer.py:232, in OptimizationViewer.load_variables(self, variables, attribute_to_column)
#     228 if not attribute_to_column:
#     229     attribute_to_column = self._DEFAULT_COLUMN_RENAMING
#     231 self.dataframe = (
# --> 232     variables.to_dataframe()
#     233     .rename(columns=attribute_to_column)[attribute_to_column.values()]
#     234     .reset_index(drop=True)
#     235 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/RHEA/lib/python3.8/site-packages/fastoad/openmdao/variables/variable_list.py:153, in VariableList.to_dataframe(self)
#     144 """
#     145 Creates a DataFrame instance from a VariableList instance.
#     146
#    (...)
#     150 :return: a pandas DataFrame instance with all variables from current list
#     151 """
#     152 var_dict = {"name": []}
# --> 153 var_dict.update({metadata_name: [] for metadata_name in self.metadata_keys()})
#     155 for variable in self:
#     156     value = self._as_list_or_item(variable.value)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/RHEA/lib/python3.8/site-packages/fastoad/openmdao/variables/variable_list.py:86, in VariableList.metadata_keys(self)
#      82 def metadata_keys(self) -> List[str]:
#      83     """
#      84     :return: the metadata keys that are common to all variables in the list
#      85     """
# ---> 86     keys = list(self[0].metadata.keys())
#      87     for var in self:
#      88         keys = [key for key in var.metadata.keys() if key in keys]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/RHEA/lib/python3.8/site-packages/fastoad/openmdao/variables/variable_list.py:511, in VariableList.__getitem__(self, key)
#     509     return self[self.names().index(key)]
#     510 else:
# --> 511     return super().__getitem__(key)
#
# IndexError: list index out of range

# %%
optim_problem = oad.optimize_problem(CONFIGURATION_FILE, overwrite=True)

# %% [markdown]
# Let's save these results:

# %%
OUTPUT_FILE = pth.join(WORK_FOLDER_PATH, "problem_outputs.xml")
CeRAS_OPT_OUTPUT_FILE = pth.join(WORK_FOLDER_PATH, "problem_outputs_CeRAS_2750nm_mdo.xml")
shutil.copy(OUTPUT_FILE, CeRAS_OPT_OUTPUT_FILE)
MISSION_FILE = pth.join(WORK_FOLDER_PATH, "flight_points.csv")
CeRAS_OPT_MISSION_FILE = pth.join(WORK_FOLDER_PATH, "mission_CeRAS_2750nm_mdo.csv")
shutil.copy(MISSION_FILE, CeRAS_OPT_MISSION_FILE)

# %% [markdown]
# The `optimizer_viewer` offers a convenient summary of the optimization result:

# %%
oad.optimization_viewer(CONFIGURATION_FILE)

# %% [markdown]
# We see that the optimizer finds a compromise between a smaller induced drag (higher aspect ratio) and a heavier wing.
#
# **Note: Finding such compromise on real aircraft is still a subject of research. Please take this result as informational.**

# %% [markdown]
# You can use the `VariableViewer` tool to see the optimization results for all variables of the system by loading the .xml output file:

# %%
RESULT_FILE = pth.join(WORK_FOLDER_PATH, "problem_outputs.xml")

# %%
oad.variable_viewer(RESULT_FILE)
