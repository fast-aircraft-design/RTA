# %% [markdown]
# <div class="row">
#   <div class="column">
#     <img src="./img/logo-onera.png" width="200">
#   </div>
#   <div class="column">
#     <img src="./img/logo-ISAE_SUPAERO.png" width="200">
#   </div>
# </div>

# %% [markdown]
# # FAST-OAD Tutorial

# %% [markdown]
# FAST-OAD is a framework for performing rapid Overall Aircraft Design. The computational core of FAST-OAD is based on the  [OpenMDAO framework](https://openmdao.org/).

# %% [markdown]
# ## 1. Setting up and analyzing the initial problem

# %% [markdown]
# To organize our work, we propose to use two user folders `data/` and `workdir/`. For instance, in `data/` we store an [XML file](./data/problem_inputs_baseline.xml) which describes the baseline regional aircraft and a [configuration file](./data/oad_process.yml) which describes the multidisciplinary analysis. In `workdir/`, we store files generated or modified by FAST-OAD.

# %%
import os.path as pth
import openmdao.api as om
import logging
import shutil
import fastoad.api as oad


DATA_FOLDER_PATH = "data"

WORK_FOLDER_PATH = "workdir"

CONFIGURATION_FILE = pth.join(WORK_FOLDER_PATH, "oad_process.yml")
SOURCE_FILE = pth.join(DATA_FOLDER_PATH, "problem_inputs_baseline.xml")

# For having log messages on screen
logging.basicConfig(level=logging.INFO, format="%(levelname)-8s: %(message)s")

# %% [markdown]
# In the configuration file, we have specified an input file name 'problem_inputs.xml'. We can ask FAST-OAD to generate the inputs of the default model with the regional aircraft parameters as default values:

# %%
oad.generate_inputs(CONFIGURATION_FILE, SOURCE_FILE, overwrite=True)
# Out:
# INFO    : Loading FAST-OAD plugin bundled
# INFO    : Loading bundles from fastoad.models
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.takeoff.__init__ (ID 45 )
# INFO    : Installed bundle fastoad.models.performances.mission.openmdao.base (ID 22 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.base (ID 33 )
# INFO    : Installed bundle fastoad.models.performances.mission.mission_definition.schema (ID 20 )
# INFO    : Installed bundle fastoad.models.performances.mission.mission_definition.mission_builder.constants (ID 14 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.altitude_change (ID 35 )
# INFO    : Installed bundle fastoad.models.performances.mission.base (ID 10 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.taxi (ID 46 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.macro_segments (ID 34 )
# INFO    : Installed bundle fastoad.models.performances.mission.mission_definition.__init__ (ID 21 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.transition (ID 47 )
# INFO    : Installed bundle fastoad.models.performances.mission.exceptions (ID 11 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.cruise (ID 36 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.__init__ (ID 48 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.time_step_base (ID 49 )
# INFO    : Installed bundle fastoad.models.performances.mission.openmdao.link_mtow (ID 23 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.ground_speed_change (ID 37 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.takeoff.takeoff (ID 44 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.mass_input (ID 39 )
# INFO    : Installed bundle fastoad.models.performances.mission.util (ID 51 )
# INFO    : Installed bundle fastoad.models.performances.mission.mission (ID 12 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.hold (ID 38 )
# INFO    : Installed bundle fastoad.models.performances.mission.polar (ID 30 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.__init__ (ID 50 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.speed_change (ID 40 )
# INFO    : Installed bundle fastoad.models.performances.mission.openmdao.__init__ (ID 29 )
# INFO    : Installed bundle fastoad.models.performances.mission.__init__ (ID 52 )
# INFO    : Installed bundle fastoad.models.performances.mission.openmdao.resources.__init__ (ID 28 )
# INFO    : Installed bundle fastoad.models.performances.mission.openmdao.mission (ID 24 )
# INFO    : Installed bundle fastoad.models.performances.__init__ (ID 53 )
# INFO    : Installed bundle fastoad.models.performances.mission.mission_definition.mission_builder.structure_builders (ID 17 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.start (ID 41 )
# INFO    : Installed bundle fastoad.models.__init__ (ID 54 )
# INFO    : Installed bundle fastoad.models.performances.mission.mission_definition.mission_builder.input_definition (ID 15 )
# INFO    : Installed bundle fastoad.models.performances.mission.openmdao.payload_range (ID 27 )
# INFO    : Installed bundle fastoad.models.performances.mission.openmdao.mission_run (ID 25 )
# INFO    : Installed bundle fastoad.models.performances.mission.mission_definition.mission_builder.mission_builder (ID 16 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.takeoff.rotation (ID 43 )
# INFO    : Installed bundle fastoad.models.performances.mission.routes (ID 32 )
# INFO    : Installed bundle fastoad.models.performances.mission.mission_definition.mission_builder.__init__ (ID 18 )
# INFO    : Installed bundle fastoad.models.performances.mission.segments.registered.takeoff.end_of_takeoff (ID 42 )
# INFO    : Installed bundle fastoad.models.performances.mission.openmdao.mission_wrapper (ID 26 )
# INFO    : Installed bundle fastoad.models.performances.mission.polar_modifier (ID 31 )
# INFO    : Installed bundle fastoad.models.performances.mission.mission_definition.exceptions (ID 13 )
# INFO    : Installed bundle fastoad.models.performances.mission.mission_definition.resources.__init__ (ID 19 )
# INFO    : Loaded variable descriptions in fastoad.models
# INFO    : Loading FAST-OAD plugin cs25
# INFO    : Loading bundles from fastoad_cs25.models
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.c_systems.c5_fixed_operational_systems_weight (ID 203 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.components.compute_planform (ID 122 )
# INFO    : Installed bundle fastoad_cs25.models.handling_qualities.tail_sizing.compute_tail_areas (ID 141 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.compute_ht_cg (ID 166 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.c_systems.c6_flight_kit_weight (ID 204 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.cd0_vt (ID 64 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.external.__init__ (ID 86 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.load_cases.compute_cg_loadcase1 (ID 169 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.c_systems.constants (ID 205 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.cd0_wing (ID 65 )
# INFO    : Installed bundle fastoad_cs25.models.constants (ID 88 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.vt.components.compute_vt_distance (ID 109 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.initialize_cl (ID 74 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.constants (ID 90 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.vt.components.compute_vt_clalpha (ID 108 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.components.compute_toc_wing (ID 124 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.vt.components.compute_vt_local_positions (ID 110 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.compute_vt_cg (ID 168 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.b_propulsion.b2_fuel_lines_weight (ID 192 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.c_systems.sum (ID 206 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.aerodynamics_landing (ID 56 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.cd_compressibility (ID 66 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.vt.components.compute_vt_mac (ID 111 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.b_propulsion.b3_unconsumables_weight (ID 193 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.vt.components.compute_vt_sweep (ID 112 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.b_propulsion.constants (ID 194 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.vt.components.__init__ (ID 113 )
# INFO    : Installed bundle fastoad_cs25.models.handling_qualities.tail_sizing.compute_vt_area (ID 142 )
# INFO    : Installed bundle fastoad_cs25.models.propulsion.fuel_propulsion.rubber_engine.exceptions (ID 153 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.cd_trim (ID 67 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.compute_aero_center (ID 89 )
# INFO    : Installed bundle fastoad_cs25.models.propulsion.fuel_propulsion.rubber_engine.__init__ (ID 156 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.load_cases.compute_cg_loadcase2 (ID 170 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.components.compute_sweep_wing (ID 123 )
# INFO    : Installed bundle fastoad_cs25.models.propulsion.fuel_propulsion.rubber_engine.rubber_engine (ID 155 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.b_propulsion.sum (ID 195 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geometry (ID 91 )
# INFO    : Installed bundle fastoad_cs25.models.handling_qualities.__init__ (ID 144 )
# INFO    : Installed bundle fastoad_cs25.models.propulsion.fuel_propulsion.rubber_engine.openmdao (ID 154 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.oswald (ID 75 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.compute_alpha (ID 68 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.vt.compute_vertical_tail (ID 114 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.b_propulsion.__init__ (ID 196 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.compute_max_cl_landing (ID 70 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.utils.cd0_lifting_surface (ID 77 )
# INFO    : Installed bundle fastoad_cs25.models.handling_qualities.tail_sizing.__init__ (ID 143 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.a_airframe.a2_fuselage_weight (ID 182 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.compute_cl_alpha (ID 69 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.resources.__init__ (ID 76 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.compute_wetted_area (ID 92 )
# INFO    : Installed bundle fastoad_cs25.models.propulsion.__init__ (ID 158 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.a_airframe.a3_empennage_weight (ID 183 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.ht.components.compute_ht_local_positions (ID 98 )
# INFO    : Installed bundle fastoad_cs25.models.propulsion.fuel_propulsion.__init__ (ID 157 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.a_airframe.a4_flight_control_weight (ID 184 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.cs25 (ID 198 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.vt.vt_global_positions (ID 115 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.components.compute_wet_area_wing (ID 125 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.fuselage.compute_cnbeta_fuselage (ID 93 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.ht.components.compute_ht_mac (ID 99 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.c_systems.__init__ (ID 207 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.constants (ID 197 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.a_airframe.a5_landing_gear_weight (ID 185 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.ht.components.compute_ht_sweep (ID 100 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.compute_cg_ratio_aft (ID 162 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.a_airframe.a6_pylons_weight (ID 186 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.utils.friction_drag (ID 78 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.ht.components.__init__ (ID 101 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.components.compute_y_wing (ID 127 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.a_airframe.a7_paint_weight (ID 187 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.__init__ (ID 80 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.fuselage.compute_fuselage (ID 94 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.vt.__init__ (ID 116 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.components.compute_x_wing (ID 126 )
# INFO    : Installed bundle fastoad_cs25.models.loops.compute_wing_area (ID 145 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg (ID 159 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.c_systems.c1_power_systems_weight (ID 199 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.ht.compute_horizontal_tail (ID 102 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.components.__init__ (ID 128 )
# INFO    : Installed bundle fastoad_cs25.models.loops.constants (ID 147 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.compute_cg_tanks (ID 163 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.a_airframe.constants (ID 188 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.d_furniture.constants (ID 208 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.utils.__init__ (ID 79 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.components.compute_b_50 (ID 117 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.profiles.profile_getter (ID 135 )
# INFO    : Installed bundle fastoad_cs25.models.loops.compute_wing_position (ID 146 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.compute_cg_control_surfaces (ID 160 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.load_cases.compute_cg_loadcase3 (ID 171 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.compute_cg_wing (ID 164 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.a_airframe.sum (ID 189 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.compute_polar (ID 71 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.constants (ID 81 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.components.compute_l1_l4 (ID 118 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.load_cases.compute_cg_loadcase4 (ID 172 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.external.xfoil.xfoil699.__init__ (ID 83 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.fuselage.__init__ (ID 95 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.components.compute_l2_l3 (ID 119 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.profiles.resources.__init__ (ID 136 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.load_cases.compute_cg_loadcases (ID 173 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.a_airframe.__init__ (ID 190 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.compute_reynolds (ID 72 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.external.xfoil.resources.__init__ (ID 82 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.external.xfoil.xfoil_polar (ID 84 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.components.compute_mac_wing (ID 120 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.profiles.__init__ (ID 137 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.compute_global_cg (ID 165 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.load_cases.compute_cg_loadcase_base (ID 174 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.b_propulsion.b1_engine_weight (ID 191 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.high_lift_aero (ID 73 )
# INFO    : Installed bundle fastoad_cs25.models.loops.wing_area_component.update_wing_area_aero (ID 148 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.compute_max_cg_ratio (ID 167 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.aerodynamics_low_speed (ID 57 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.ht.components.compute_ht_chords (ID 96 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.ht.ht_global_positions (ID 103 )
# INFO    : Installed bundle fastoad_cs25.models.handling_qualities.tail_sizing.compute_ht_area (ID 140 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.aerodynamics_high_speed (ID 55 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.load_cases.__init__ (ID 175 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.__init__ (ID 87 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.ht.components.compute_ht_cl_alpha (ID 97 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.c_systems.c2_life_support_systems_weight (ID 200 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.components.compute_mfw (ID 121 )
# INFO    : Installed bundle fastoad_cs25.models.handling_qualities.compute_static_margin (ID 139 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.compute_cg_others (ID 161 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.c_systems.c3_navigation_systems_weight (ID 201 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.ht.__init__ (ID 104 )
# INFO    : Installed bundle fastoad_cs25.models.loops.wing_area_component.update_wing_area_geom (ID 149 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.external.xfoil.__init__ (ID 85 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.c_systems.c4_transmissions_systems_weight (ID 202 )
# INFO    : Installed bundle fastoad_cs25.models.loops.__init__ (ID 151 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.nacelle_pylons.compute_nacelle_pylons (ID 105 )
# INFO    : Installed bundle fastoad_cs25.models.loops.wing_area_component.__init__ (ID 150 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.__init__ (ID 221 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.update_mlg (ID 176 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.nacelle_pylons.__init__ (ID 106 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.constants (ID 178 )
# INFO    : Installed bundle fastoad_cs25.models.weight.weight (ID 222 )
# INFO    : Installed bundle fastoad_cs25.models.propulsion.fuel_propulsion.rubber_engine.constants (ID 152 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.cg_components.__init__ (ID 177 )
# INFO    : Installed bundle fastoad_cs25.models.weight.__init__ (ID 223 )
# INFO    : Installed bundle fastoad_cs25.models.__init__ (ID 224 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.aerodynamics_takeoff (ID 58 )
# INFO    : Installed bundle fastoad_cs25.models.weight.cg.__init__ (ID 179 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.d_furniture.d1_cargo_configuration_weight (ID 209 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.cd0 (ID 59 )
# INFO    : Installed bundle fastoad_cs25.models.weight.constants (ID 180 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.d_furniture.d2_passenger_seats_weight (ID 210 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.d_furniture.d3_food_water_weight (ID 211 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.d_furniture.d4_security_kit_weight (ID 212 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.d_furniture.d5_toilets_weight (ID 213 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.cd0_fuselage (ID 60 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.profiles.profile (ID 134 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.d_furniture.sum (ID 214 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.a_airframe.a1_wing_weight (ID 181 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.d_furniture.__init__ (ID 215 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.__init__ (ID 138 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.vt.components.compute_vt_chords (ID 107 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.__init__ (ID 133 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.cd0_ht (ID 61 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.__init__ (ID 132 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.e_crew.crew_weight (ID 216 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.e_crew.__init__ (ID 217 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.wing_global_positions (ID 131 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.compute_wing (ID 129 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.cd0_nacelles_pylons (ID 62 )
# INFO    : Installed bundle fastoad_cs25.models.geometry.geom_components.wing.constants (ID 130 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.mass_breakdown (ID 218 )
# INFO    : Installed bundle fastoad_cs25.models.aerodynamics.components.cd0_total (ID 63 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.payload (ID 219 )
# INFO    : Installed bundle fastoad_cs25.models.weight.mass_breakdown.update_mlw_and_mzfw (ID 220 )
# INFO    : Loaded variable descriptions in fastoad_cs25.models
# INFO    : Loading FAST-OAD plugin rta
# INFO    : Loading bundles from rta.models
# INFO    : Installed bundle rta.models.geometry.geom_components.__init__ (ID 250 )
# INFO    : Installed bundle rta.models.weight.cg.cg_components.compute_cg_loadcase4 (ID 284 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.c_systems.ATA23_communication_systems_weight (ID 307 )
# INFO    : Installed bundle rta.models.geometry.geom_components.fuselage.__init__ (ID 240 )
# INFO    : Installed bundle rta.models.propulsion.fuel_engine.turboprop_engine.engine_components.Combustor (ID 256 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.a_airframe.a1_wing_weight (ID 295 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.c_systems.ATA24_electrical_systems_weight (ID 308 )
# INFO    : Installed bundle rta.models.__init__ (ID 338 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.a_airframe.a6_nacelles_weight (ID 296 )
# INFO    : Installed bundle rta.models.geometry.geom_components.fuselage.compute_fuselage (ID 239 )
# INFO    : Installed bundle rta.models.propulsion.fuel_engine.turboprop_engine.engine_components.Fuel_Data (ID 259 )
# INFO    : Installed bundle rta.models.aerodynamics.components.cd0_fuselage (ID 226 )
# INFO    : Installed bundle rta.models.propulsion.fuel_engine.turboprop_engine.engine_components.__init__ (ID 268 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.a_airframe.constants (ID 297 )
# INFO    : Installed bundle rta.models.aerodynamics.aerodynamics_takeoff_RTA (ID 225 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.c_systems.ATA25_flight_furnishing_systems_weight (ID 309 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.e_operational.operational_items_weight (ID 330 )
# INFO    : Installed bundle rta.models.geometry.geom_components.nacelle.compute_nacelle (ID 241 )
# INFO    : Installed bundle rta.models.propulsion.fuel_engine.turboprop_engine.sizing.__init__ (ID 273 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.a_airframe.sum (ID 298 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.c_systems.__init__ (ID 318 )
# INFO    : Installed bundle rta.models.propulsion.fuel_engine.turboprop_engine.ML_TP_L1 (ID 269 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.d_furniture.ATA2580_insulation_weight (ID 320 )
# INFO    : Installed bundle rta.models.aerodynamics.components.cd0_nacelle_pylons_TP (ID 227 )
# INFO    : Installed bundle rta.models.geometry.geom_components.nacelle.__init__ (ID 242 )
# INFO    : Installed bundle rta.models.propulsion.fuel_engine.turboprop_engine.engine_components.High_Pressure_Compressor (ID 260 )
# INFO    : Installed bundle rta.models.weight.cg.cg_components.compute_global_cg (ID 287 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.a_airframe.__init__ (ID 299 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.c_systems.ATA26_fire_systems_weight (ID 310 )
# INFO    : Installed bundle rta.models.aerodynamics.components.cd0_total (ID 228 )
# INFO    : Installed bundle rta.models.propulsion.fuel_engine.turboprop_engine.engine_components.Compression_Nozzle (ID 257 )
# INFO    : Installed bundle rta.models.weight.cg.cg_components.compute_max_cg_ratio (ID 288 )
# INFO    : Installed bundle rta.models.aerodynamics.components.lg_effect (ID 231 )
# INFO    : Installed bundle rta.models.propulsion.fuel_engine.turboprop_engine.engine_components.Low_Pressure_Compressor (ID 262 )
# INFO    : Installed bundle rta.models.weight.cg.constants (ID 291 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.d_furniture.ATA25_furnishing_weight (ID 321 )
# INFO    : Installed bundle rta.models.aerodynamics.components.cd0_wing (ID 229 )
# INFO    : Installed bundle rta.models.propulsion.fuel_engine.turboprop_engine.tests.test_ML_TP_L1 (ID 274 )
# INFO    : Installed bundle rta.models.weight.cg.cg_components.__init__ (ID 290 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.b_propulsion.constants (ID 300 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.d_furniture.ATA33_lighting_weight (ID 322 )
# INFO    : Installed bundle rta.models.propulsion.fuel_engine.turboprop_engine.tests.__init__ (ID 275 )
# INFO    : Installed bundle rta.models.weight.cg.cg_components.compute_cg_others (ID 285 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.c_systems.ATA27_flight_control_systems_weight (ID 311 )
# INFO    : Installed bundle rta.models.aerodynamics.components.initialize_in (ID 230 )
# INFO    : Installed bundle rta.models.aerodynamics.components.tests.test_components (ID 234 )
# INFO    : Installed bundle rta.models.propulsion.fuel_engine.turboprop_engine.engine_components.Low_Pressure_Turbine (ID 263 )
# INFO    : Installed bundle rta.models.propulsion.fuel_engine.turboprop_engine.engine_components.Ram (ID 266 )
# INFO    : Installed bundle rta.models.weight.cg.cg_components.compute_propulsion_cg (ID 289 )
# INFO    : Installed bundle rta.models.geometry.geom_components.tests.test_components (ID 243 )
# INFO    : Installed bundle rta.models.propulsion.fuel_engine.turboprop_engine.engine_components.High_Pressure_Turbine (ID 261 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.b_propulsion.sum (ID 301 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.d_furniture.ATA35_oxygen_weight (ID 323 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.e_operational.sum (ID 331 )
# INFO    : Installed bundle rta.models.aerodynamics.components.OEI_effect (ID 232 )
# INFO    : Installed bundle rta.models.propulsion.fuel_engine.turboprop_engine.sizing.Prop_sizing (ID 271 )
# INFO    : Installed bundle rta.models.weight.cg.tests.__init__ (ID 293 )
# INFO    : Installed bundle rta.models.propulsion.fuel_engine.__init__ (ID 277 )
# INFO    : Installed bundle rta.models.propulsion.fuel_engine.turboprop_engine.engine_components.Expansion_Nozzle (ID 258 )
# INFO    : Installed bundle rta.models.geometry.__init__ (ID 251 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.c_systems.ATA29_hydraulic_systems_weight (ID 312 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.e_operational.__init__ (ID 332 )
# INFO    : Installed bundle rta.models.propulsion.fuel_engine.turboprop_engine.__init__ (ID 276 )
# INFO    : Installed bundle rta.models.weight.cg.__init__ (ID 294 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.d_furniture.ATA38_water_weight (ID 324 )
# INFO    : Installed bundle rta.models.geometry.geom_components.tests.__init__ (ID 244 )
# INFO    : Installed bundle rta.models.propulsion.fuel_engine.turboprop_engine.openmdao (ID 270 )
# INFO    : Installed bundle rta.models.weight.cg.cg_components.compute_cg_flight_controls (ID 280 )
# INFO    : Installed bundle rta.models.weight.cg.tests.test_cg_components (ID 292 )
# INFO    : Installed bundle rta.models.weight.cg.cg_components.compute_cg_loadcase1 (ID 281 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.b_propulsion.turboprop_weight (ID 302 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.c_systems.ATA30_device_systems_weight (ID 313 )
# INFO    : Installed bundle rta.models.geometry.geom_components.wing.components.compute_toc_wing_rta (ID 245 )
# INFO    : Installed bundle rta.models.propulsion.__init__ (ID 278 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.mass_breakdown (ID 333 )
# INFO    : Installed bundle rta.models.aerodynamics.components.oswald (ID 233 )
# INFO    : Installed bundle rta.models.geometry.geom_components.wing.components.compute_wet_area_wing_rta (ID 246 )
# INFO    : Installed bundle rta.models.loops.compute_engine_size (ID 252 )
# INFO    : Installed bundle rta.models.weight.cg.cg_components.compute_cg_loadcase2 (ID 282 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.c_systems.ATA34_navigation_systems_weight (ID 314 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.d_furniture.ATA5345_5347_interior_weight (ID 325 )
# INFO    : Installed bundle rta.models.geometry.geom_components.wing.compute_wing_rta (ID 248 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.b_propulsion.__init__ (ID 303 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.c_systems.ATA49_auxiliary_power_systems_weight (ID 315 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.tests.test_mass_breakdown (ID 334 )
# INFO    : Installed bundle rta.models.loops.__init__ (ID 253 )
# INFO    : Installed bundle rta.models.propulsion.fuel_engine.turboprop_engine.sizing.TP_sizing (ID 272 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.tests.__init__ (ID 335 )
# INFO    : Installed bundle rta.models.geometry.geom_components.wing.components.__init__ (ID 247 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.constants (ID 304 )
# INFO    : Installed bundle rta.models.aerodynamics.constants (ID 237 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.c_systems.ATA21_environmental_control_systems_weight (ID 305 )
# INFO    : Installed bundle rta.models.aerodynamics.components.tests.__init__ (ID 235 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.c_systems.ATA22_autoflight_systems_weight (ID 306 )
# INFO    : Installed bundle rta.models.aerodynamics.components.__init__ (ID 236 )
# INFO    : Installed bundle rta.models.propulsion.fuel_engine.turboprop_engine.engine_components.Power_Turbine (ID 264 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.d_furniture.constants (ID 326 )
# INFO    : Installed bundle rta.models.aerodynamics.__init__ (ID 238 )
# INFO    : Installed bundle rta.models.propulsion.fuel_engine.constants (ID 254 )
# INFO    : Installed bundle rta.models.weight.cg.cg_components.compute_cg_loadcase3 (ID 283 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.c_systems.constants (ID 316 )
# INFO    : Installed bundle rta.models.weight.__init__ (ID 337 )
# INFO    : Installed bundle rta.models.propulsion.fuel_engine.turboprop_engine.engine_components.Thrust (ID 267 )
# INFO    : Installed bundle rta.models.propulsion.fuel_engine.turboprop_engine.base (ID 255 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.d_furniture.sum (ID 327 )
# INFO    : Installed bundle rta.models.weight.cg.cg (ID 279 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.c_systems.sum (ID 317 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.e_operational.operational_equipment_weight (ID 329 )
# INFO    : Installed bundle rta.models.propulsion.fuel_engine.turboprop_engine.engine_components.Propeller (ID 265 )
# INFO    : Installed bundle rta.models.weight.cg.cg_components.compute_cg_ratio_aft (ID 286 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.d_furniture.ATA2510_crew_seats_weight (ID 319 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.d_furniture.__init__ (ID 328 )
# INFO    : Installed bundle rta.models.weight.mass_breakdown.__init__ (ID 336 )
# INFO    : Installed bundle rta.models.geometry.geom_components.wing.__init__ (ID 249 )
# INFO    : Loaded variable descriptions in rta.models
# WARNING : The following variables have NaN values: ['data:geometry:wing:root:dihedral']
# INFO    : Problem inputs written in D:\enguyen\rhea_antoine_prunet\rta\notebooks\workdir\problem_inputs.xml
# 'D:/enguyen/rhea_antoine_prunet/rta/notebooks/workdir/problem_inputs.xml'

# %% [markdown]
# You can now checkout the generated [input file](./workdir/problem_inputs.xml). As shown previously in the user file architecture, the values in this file can be modified by the user and will be considered by FAST-OAD when executing a computational process.

# %% [markdown]
# A useful feature that FAST-OAD provides is to list the variables of the model defined in the configuration file:

# %%
oad.list_variables(CONFIGURATION_FILE)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>NAME</th>
#       <th>I/O</th>
#       <th>DESCRIPTION</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>data:TLAR:NPAX</td>
#       <td>IN</td>
#       <td>top-level requirement: number of passengers, assuming a classic eco/business class repartition</td>
#     </tr>
#     <tr>
#       <td>data:TLAR:approach_speed</td>
#       <td>IN</td>
#       <td>top-level requirement: approach speed</td>
#     </tr>
#     <tr>
#       <td>data:TLAR:cruise_mach</td>
#       <td>IN</td>
#       <td>Input defined by the mission.</td>
#     </tr>
#     <tr>
#       <td>data:TLAR:range</td>
#       <td>IN</td>
#       <td>Input defined by the mission.</td>
#     </tr>
#     <tr>
#       <td>data:aerodynamics:aircraft:cruise:CL0</td>
#       <td>IN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>data:aerodynamics:aircraft:landing:CL_max</td>
#       <td>IN</td>
#       <td>maximum lift coefficient in landing conditions</td>
#     </tr>
#     <tr>
#       <td>data:aerodynamics:aircraft:low_speed:CL0</td>
#       <td>IN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>data:aerodynamics:aircraft:low_speed:DCD_ext</td>
#       <td>IN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>data:aerodynamics:aircraft:takeoff:mach</td>
#       <td>IN</td>
#       <td>considered Mach number for takeoff phase</td>
#     </tr>
#     <tr>
#       <td>data:geometry:cabin:aisle_width</td>
#       <td>IN</td>
#       <td>width of aisles</td>
#     </tr>
#     <tr>
#       <td>data:geometry:cabin:crew_count:technical</td>
#       <td>IN</td>
#       <td>number of technical crew members</td>
#     </tr>
#     <tr>
#       <td>data:geometry:cabin:exit_width</td>
#       <td>IN</td>
#       <td>width of exits</td>
#     </tr>
#     <tr>
#       <td>data:geometry:cabin:seats:economical:count_by_row</td>
#       <td>IN</td>
#       <td>number of economical class seats along width</td>
#     </tr>
#     <tr>
#       <td>data:geometry:cabin:seats:economical:length</td>
#       <td>IN</td>
#       <td>length of economical class seats</td>
#     </tr>
#     <tr>
#       <td>data:geometry:cabin:seats:economical:width</td>
#       <td>IN</td>
#       <td>width of economical class seats</td>
#     </tr>
#     <tr>
#       <td>data:geometry:flap:chord_ratio</td>
#       <td>IN</td>
#       <td>mean value of (flap chord)/(section chord)</td>
#     </tr>
#     <tr>
#       <td>data:geometry:flap:span_ratio</td>
#       <td>IN</td>
#       <td>ratio (width of flaps)/(total span)</td>
#     </tr>
#     <tr>
#       <td>data:geometry:has_T_tail</td>
#       <td>IN</td>
#       <td>0=horizontal tail is attached to fuselage / 1=horizontal tail is attached to top of vertical tail</td>
#     </tr>
#     <tr>
#       <td>data:geometry:horizontal_tail:aspect_ratio</td>
#       <td>IN</td>
#       <td>aspect ratio of horizontal tail</td>
#     </tr>
#     <tr>
#       <td>data:geometry:horizontal_tail:sweep_25</td>
#       <td>IN</td>
#       <td>sweep angle at 25% chord of horizontal tail</td>
#     </tr>
#     <tr>
#       <td>data:geometry:horizontal_tail:taper_ratio</td>
#       <td>IN</td>
#       <td>taper ratio of horizontal tail</td>
#     </tr>
#     <tr>
#       <td>data:geometry:horizontal_tail:thickness_ratio</td>
#       <td>IN</td>
#       <td>thickness ratio of horizontal tail</td>
#     </tr>
#     <tr>
#       <td>data:geometry:propulsion:engine:count</td>
#       <td>IN</td>
#       <td>number of engines</td>
#     </tr>
#     <tr>
#       <td>data:geometry:propulsion:engine:y_ratio</td>
#       <td>IN</td>
#       <td>engine position with respect to total span</td>
#     </tr>
#     <tr>
#       <td>data:geometry:propulsion:layout</td>
#       <td>IN</td>
#       <td>position of engines (1=under the wing / 2=rear fuselage)</td>
#     </tr>
#     <tr>
#       <td>data:geometry:propulsion:propeller:B</td>
#       <td>IN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>data:geometry:propulsion:pylon:wetted_area</td>
#       <td>IN</td>
#       <td>wetted area of pylon</td>
#     </tr>
#     <tr>
#       <td>data:geometry:slat:chord_ratio</td>
#       <td>IN</td>
#       <td>mean value of slat chord)/(section chord)</td>
#     </tr>
#     <tr>
#       <td>data:geometry:slat:span_ratio</td>
#       <td>IN</td>
#       <td>ratio (width of slats)/(total span)</td>
#     </tr>
#     <tr>
#       <td>data:geometry:vertical_tail:aspect_ratio</td>
#       <td>IN</td>
#       <td>aspect ratio of vertical tail</td>
#     </tr>
#     <tr>
#       <td>data:geometry:vertical_tail:sweep_25</td>
#       <td>IN</td>
#       <td>sweep angle at 25% chord of vertical tail</td>
#     </tr>
#     <tr>
#       <td>data:geometry:vertical_tail:taper_ratio</td>
#       <td>IN</td>
#       <td>taper ratio of vertical tail</td>
#     </tr>
#     <tr>
#       <td>data:geometry:vertical_tail:thickness_ratio</td>
#       <td>IN</td>
#       <td>thickness ratio of vertical tail</td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:aspect_ratio</td>
#       <td>IN</td>
#       <td>wing aspect ratio</td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:kink:span_ratio</td>
#       <td>IN</td>
#       <td>ratio (Y-position of kink)/(semi-span)</td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:root:dihedral</td>
#       <td>IN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:spar_ratio:front:kink</td>
#       <td>IN</td>
#       <td>ratio (front spar position)/(chord length) at wing kink</td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:spar_ratio:front:root</td>
#       <td>IN</td>
#       <td>ratio (front spar position)/(chord length) at wing root</td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:spar_ratio:front:tip</td>
#       <td>IN</td>
#       <td>ratio (front spar position)/(chord length) at wing tip</td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:spar_ratio:rear:kink</td>
#       <td>IN</td>
#       <td>ratio (rear spar position)/(chord length) at wing kink</td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:spar_ratio:rear:root</td>
#       <td>IN</td>
#       <td>ratio (rear spar position)/(chord length) at wing root</td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:spar_ratio:rear:tip</td>
#       <td>IN</td>
#       <td>ratio (rear spar position)/(chord length) at wing tip</td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:sweep_100_ratio</td>
#       <td>IN</td>
#       <td>ratio inner/outer for sweep angles at trailing edge of wing</td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:sweep_25</td>
#       <td>IN</td>
#       <td>sweep angle at 25% chord of wing</td>
#     </tr>
#     <tr>
#       <td>data:geometry:wing:virtual_taper_ratio</td>
#       <td>IN</td>
#       <td>taper ratio of wing computed from virtual root chord</td>
#     </tr>
#     <tr>
#       <td>data:handling_qualities:static_margin:target</td>
#       <td>IN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>data:load_case:gust_intensity</td>
#       <td>IN</td>
#       <td>a factor for gust load alleviation, 1.0: full gust load is applied, 0.0: gust load is fully alleviated</td>
#     </tr>
#     <tr>
#       <td>data:load_case:lc1:U_gust</td>
#       <td>IN</td>
#       <td>gust vertical speed for sizing load case 1 (gust with minimum aircraft mass)</td>
#     </tr>
#     <tr>
#       <td>data:load_case:lc1:Vc_EAS</td>
#       <td>IN</td>
#       <td>equivalent air speed for sizing load case 1 (gust with minimum aircraft mass)</td>
#     </tr>
#     <tr>
#       <td>data:load_case:lc1:altitude</td>
#       <td>IN</td>
#       <td>altitude for sizing load case 1 (gust with minimum aircraft mass)</td>
#     </tr>
#     <tr>
#       <td>data:load_case:lc2:U_gust</td>
#       <td>IN</td>
#       <td>gust vertical speed for sizing load case 2 (gust with maximum aircraft mass)</td>
#     </tr>
#     <tr>
#       <td>data:load_case:lc2:Vc_EAS</td>
#       <td>IN</td>
#       <td>equivalent air speed for sizing load case 2 (gust with maximum aircraft mass)</td>
#     </tr>
#     <tr>
#       <td>data:load_case:lc2:altitude</td>
#       <td>IN</td>
#       <td>altitude for sizing load case 2 (gust with maximum aircraft mass)</td>
#     </tr>
#     <tr>
#       <td>data:load_case:manoeuvre_load_factor</td>
#       <td>IN</td>
#       <td>limit positive manoeuvring load factor</td>
#     </tr>
#     <tr>
#       <td>data:mission:sizing:ISA_o

# %% [markdown]
# The variable viewer provides a interactive way of navigating throught the variables and modifying them.

# %%
INPUT_FILE = pth.join(WORK_FOLDER_PATH, "problem_inputs.xml")
oad.variable_viewer(INPUT_FILE)
# Out:
# D:\enguyen\rhea_antoine_prunet\venv\lib\site-packages\jupyter_client\session.py:721: UserWarning: Message serialization failed with:
# Out of range float values are not JSON compliant
# Supporting this message is deprecated in jupyter-client 7, please make sure your message is JSON-compliant
#   content = self.pack(content)
# VBox(children=(HBox(children=(Button(description='Load', icon='upload', style=ButtonStyle(), tooltip='Load the…

# %% [markdown]
# Another useful feature is to list the modules of the model defined in the configuration file:

# %%
oad.list_modules(CONFIGURATION_FILE)
# api.list_modules(CONFIGURATION_FILE, verbose=True) # Use this line instead of the previous one for detailed information (text format only)
# Out:
# <table>
# <tbody>
# <tr><td>AVAILABLE MODULE IDENTIFIERS            </td><td>MODULE PATH                                                                                                                   </td></tr>
# <tr><td>fastoad.aerodynamics.highspeed.legacy   </td><td>D:\enguyen\rhea_antoine_prunet\venv\lib\site-packages\fastoad_cs25\models\aerodynamics\aerodynamics_high_speed.py             </td></tr>
# <tr><td>fastoad.aerodynamics.landing.legacy     </td><td>D:\enguyen\rhea_antoine_prunet\venv\lib\site-packages\fastoad_cs25\models\aerodynamics\aerodynamics_landing.py                </td></tr>
# <tr><td>fastoad.aerodynamics.lowspeed.legacy    </td><td>D:\enguyen\rhea_antoine_prunet\venv\lib\site-packages\fastoad_cs25\models\aerodynamics\aerodynamics_low_speed.py              </td></tr>
# <tr><td>fastoad.aerodynamics.takeoff.legacy     </td><td>D:\enguyen\rhea_antoine_prunet\venv\lib\site-packages\fastoad_cs25\models\aerodynamics\aerodynamics_takeoff.py                </td></tr>
# <tr><td>fastoad.geometry.legacy                 </td><td>D:\enguyen\rhea_antoine_prunet\venv\lib\site-packages\fastoad_cs25\models\geometry\geometry.py                                </td></tr>
# <tr><td>fastoad.handling_qualities.static_margin</td><td>D:\enguyen\rhea_antoine_prunet\venv\lib\site-packages\fastoad_cs25\models\handling_qualities\compute_static_margin.py         </td></tr>
# <tr><td>fastoad.handling_qualities.tail_sizing  </td><td>D:\enguyen\rhea_antoine_prunet\venv\lib\site-packages\fastoad_cs25\models\handling_qualities\tail_sizing\compute_tail_areas.py</td></tr>
# <tr><td>fastoad.loop.wing_area                  </td><td>D:\enguyen\rhea_antoine_prunet\venv\lib\site-packages\fastoad_cs25\models\loops\compute_wing_area.py                          </td></tr>
# <tr><td>fastoad.loop.wing_position              </td><td>D:\enguyen\rhea_antoine_prunet\venv\lib\site-packages\fastoad_cs25\models\loops\compute_wing_position.py                      </td></tr>
# <tr><td>fastoad.mass_performances.compute_MTOW  </td><td>D:\enguyen\rhea_antoine_prunet\venv\lib\site-packages\fastoad\models\performances\mission\openmdao\link_mtow.py               </td></tr>
# <tr><td>fastoad.performances.mission            </td><td>D:\enguyen\rhea_antoine_prunet\venv\lib\site-packages\fastoad\models\performances\mission\openmdao\mission.py                 </td></tr>
# <tr><td>fastoad.performances.payload_range      </td><td>D:\enguyen\rhea_antoine_prunet\venv\lib\site-packages\fastoad\models\performances\mission\openmdao\payload_range.py           </td></tr>
# <tr><td>fastoad.weight.legacy                   </td><td>D:\enguyen\rhea_antoine_prunet\venv\lib\site-packages\fastoad_cs25\models\weight\weight.py                                    </td></tr>
# <tr><td>rta.aerodynamics.takeoff                </td><td>D:\enguyen\rhea_antoine_prunet\rta\models\aerodynamics\aerodynamics_takeoff_RTA.py                                            </td></tr>
# <tr><td>rta.loop.engine_size                    </td><td>D:\enguyen\rhea_antoine_prunet\rta\models\loops\compute_engine_size.py                                                        </td></tr>
# <tr><td>rta.propulsion.propeller_sizing         </td><td>D:\enguyen\rhea_antoine_prunet\rta\models\propulsion\fuel_engine\turboprop_engine\sizing\Prop_sizing.py                       </td></tr>
# <tr><td>rta.propulsion.turboprop_sizing         </td><td>D:\enguyen\rhea_antoine_prunet\rta\models\propulsion\fuel_engine\turboprop_engine\sizing\TP_sizing.py                         </td></tr>
# <tr><td>AVAILABLE PROPULSION WRAPPER IDENTIFIERS</td><td>MODULE PATH                                                                                                                   </td></tr>
# <tr><td>fastoad.wrapper.propulsion.rubber_engine</td><td>D:\enguyen\rhea_antoine_prunet\venv\lib\site-packages\fastoad_cs25\models\propulsion\fuel_propulsion\rubber_engine\openmdao.py</td></tr>
# <tr><td>rta.wrapper.propulsion.ML_TP_L1         </td><td>D:\enguyen\rhea_antoine_prunet\rta\models\propulsion\fuel_engine\turboprop_engine\openmdao.py                                 </td></tr>
# </tbody>
# </table>

# %% [markdown]
# Another useful feature is the [N2 diagram](http://openmdao.org/twodocs/versions/latest/basic_guide/make_n2.html) visualization available in OpenMDAO to see the structure of the model:

# %%
N2_FILE = pth.join(WORK_FOLDER_PATH, "n2.html")
oad.write_n2(CONFIGURATION_FILE, N2_FILE, overwrite=True)
from IPython.display import IFrame

IFrame(src=N2_FILE, width="100%", height="500px")
# Out:
# INFO    : N2 diagram written in D:\enguyen\rhea_antoine_prunet\rta\notebooks\workdir\n2.html
#         <iframe
#             width="100%"
#             height="500px"
#             src="workdir\n2.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Alternatively, you can use [WhatsOpt](https://github.com/OneraHub/WhatsOpt-Doc#whatsopt-documentation) as a web service to generate the XDSM of the problem.
#
# *This command requires internet access and can take some time (~ 1 minute on the first run), so it is currently deactivated, but feel free to uncomment these lines.*

# %%
# XDSM_FILE = pth.join(WORK_FOLDER_PATH, 'xdsm.html')
# oad.write_xdsm(CONFIGURATION_FILE, XDSM_FILE, overwrite=True)
# from IPython.display import IFrame
# IFrame(src=XDSM_FILE, width='100%', height='500px')

# %% [markdown]
# ## 2. Running your first MDA

# %% [markdown]
# ### Conventional aircraft
# Here we run an MDA, that is solving the multidisciplinary couplings using the different nested solvers in the model, without running the optimization problem even if it is defined in the configuration file.
#
# *(This run should take around 20 seconds)*

# %%
eval_problem = oad.evaluate_problem(CONFIGURATION_FILE, overwrite=True)
# Out:
# ---------------------------------------------------------------------------
# FASTNanInInputsError                      Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 eval_problem = oad.evaluate_problem(CONFIGURATION_FILE, overwrite=True)
#
# File ~\rhea_antoine_prunet\venv\lib\site-packages\fastoad\cmd\api.py:738, in evaluate_problem(configuration_file_path, overwrite)
#     727 def evaluate_problem(
#     728     configuration_file_path: Union[str, PathLike], overwrite: bool = False
#     729 ) -> FASTOADProblem:
#     730     """
#     731     Runs model according to provided problem file
#     732
#    (...)
#     736     :raise FastPathExistsError: if overwrite==False and output data file of problem already exists
#     737     """
# --> 738     return _run_problem(configuration_file_path, overwrite, "run_model")
#
# File ~\rhea_antoine_prunet\venv\lib\site-packages\fastoad\cmd\api.py:691, in _run_problem(configuration_file_path, overwrite, mode, auto_scaling)
#     689 conf = FASTOADProblemConfigurator(configuration_file_path)
#     690 conf._set_configuration_modifier(_PROBLEM_CONFIGURATOR)
# --> 691 problem = conf.get_problem(read_inputs=True, auto_scaling=auto_scaling)
#     693 outputs_path = as_path(problem.output_file_path)
#     694 if not overwrite and outputs_path.exists():
#
# File ~\rhea_antoine_prunet\venv\lib\site-packages\fastoad\io\configuration\configuration.py:136, in FASTOADProblemConfigurator.get_problem(self, read_inputs, auto_scaling)
#     133 problem.model_options = model_options
#     135 if read_inputs:
# --> 136     problem.read_inputs()
#     138 driver = self._data.get(KEY_DRIVER, "")
#     139 if driver:
#
# File ~\rhea_antoine_prunet\venv\lib\site-packages\fastoad\openmdao\problem.py:164, in FASTOADProblem.read_inputs(self)
#     160 def read_inputs(self):
#     161     """
#     162     Reads inputs of the problem.
#     163     """
# --> 164     self._input_file_variables, self.additional_variables = self._get_problem_inputs()
#     166     if self._metadata and self._metadata["setup_status"] == _SetupStatus.POST_SETUP:
#     167         self._set_input_values_post_setup()
#
# File ~\rhea_antoine_prunet\venv\lib\site-packages\fastoad\openmdao\problem.py:221, in FASTOADProblem._get_problem_inputs(self)
#     218 non_filled_variable_names = self._get_remaining_nan_variable_names(input_file_variables)
#     220 if non_filled_variable_names:
# --> 221     raise FASTNanInInputsError(self.input_file_path, non_filled_variable_names)
#     223 return input_file_variables, unused_variables
#
# FASTNanInInputsError: (FASTNanInInputsError(...), "NaN values found in inputs. Please check that D:/enguyen/rhea_antoine_prunet/rta/notebooks/workdir/problem_inputs.xml contains following variables and that they are not NaN: ['data:geometry:wing:root:dihedral']")

# %% [markdown]
# The outputs of the analysis are written to the output file specified in the configuration file. Alternatively, to inspect the result of the MDA, the variable viewer may be used as follow:

# %%
OUTPUT_FILE = pth.join(WORK_FOLDER_PATH, "problem_outputs.xml")
oad.variable_viewer(OUTPUT_FILE)
# Out:
# VBox(children=(HBox(children=(Button(description='Load', icon='upload', style=ButtonStyle(), tooltip='Load the…
